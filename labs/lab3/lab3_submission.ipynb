# %%
# Import modules
import osmnx as ox 

import numpy as np
import pandas as pd
import geopandas as gpd

from shapely.geometry.polygon import Polygon
from shapely.geometry.multipolygon import MultiPolygon
from shapely.geometry import LineString, MultiLineString

# %%
# Specify type of data
tags = {'building': True}

# Download building geometries from OSM
gdf = ox.geometries_from_place('Cleveland, Ohio, USA', tags)
# Out:
# /Users/lily/opt/anaconda3/envs/lab3/lib/python3.8/site-packages/osmnx/geometries.py:805: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# /Users/lily/opt/anaconda3/envs/lab3/lib/python3.8/site-packages/osmnx/geometries.py:805: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):

# %%
print(gdf.shape)
# Out:
# (38392, 208)

# %%
print(gdf.columns.tolist())
# Out:
# ['source', 'geometry', 'amenity', 'access', 'parking', 'name', 'addr:city', 'addr:housenumber', 'addr:postcode', 'addr:state', 'addr:street', 'tourism', 'barrier', 'layer', 'wheelchair', 'level', 'note', 'fee', 'lit', 'maxheight', 'operator', 'smoothness', 'surface', 'description', 'network', 'building', 'leisure', 'sport', 'website', 'capacity', 'historic', 'material', 'memorial', 'construction:amenity', 'opening_date', 'nodes', 'loc_name', 'name:en', 'wikidata', 'wikipedia', 'ele', 'gnis:county_id', 'gnis:created', 'gnis:edited', 'gnis:feature_id', 'gnis:state_id', 'old_name', 'alt_name', 'start_date', 'opening_hours', 'gnis:county_name', 'gnis:import_uuid', 'denomination', 'religion', 'aeroway', 'height', 'building:levels', 'heritage', 'phone', 'townhall:type', 'gnis:reviewed', 'operator:type', 'operator:wikidata', 'operator:wikipedia', 'short_name', 'brand', 'brand:wikidata', 'brand:wikipedia', 'healthcare', 'cuisine', 'drive_through', 'takeaway', 'shop', 'dispensing', 'internet_access', 'internet_access:fee', 'outdoor_seating', 'social_facility', 'smoking', 'addr:country', 'air_conditioning', 'museum', 'toilets:wheelchair', 'building:flats', 'park_ride', 'roof:levels', 'roof:shape', 'landuse', 'power', 'building:levels:underground', 'garden:type', 'addr:housename', 'supervised', 'email', 'ref:nrhp', 'architect', 'heritage:operator', 'heritage:website', 'nrhp:criteria', 'nrhp:inscription_date', 'old_name:1940-1976', 'protection_title', 'source_ref', 'local_name', 'office', 'social_facility:for', 'government', 'bar', 'trade', 'atm', 'second_hand', 'branch', 'rooms', 'stars', 'facebook', 'image', 'nrhp:nhl', 'ref', 'ship:type', 'name:es', 'official_name', 'bus', 'network:wikidata', 'public_transport', 'hgv', 'motor_vehicle', 'tourist_bus', 'theatre:type', 'opening_hours:covid19', 'craft', 'fax', 'shelter_type', 'roof:height', 'fixme', 'ship', 'studio', 'url', 'delivery', 'roof:colour', 'man_made', 'tower:construction', 'tower:type', 'microbrewery', 'clothes', 'building:material', 'highway', 'route_ref', 'description:en', 'capacity:disabled', 'location', 'occupant', 'name:etymology:wikidata', 'telecom', 'content', 'disused:amenity', 'blood:plasma', 'pet', 'healthcare:speciality', 'karaoke', 'brewery', 'building:use', 'generator:method', 'generator:output:electricity', 'generator:source', 'generator:type', 'service', 'building:start_date', 'note2', 'bin', 'toilets:disposal', 'unisex', 'abandoned', 'designation', 'construction', 'product', 'elevation', 'military', 'club', 'abandoned:building', 'area', 'contact:facebook', 'payment:american_express', 'payment:cash', 'payment:checks', 'payment:debit_cards', 'payment:discover_card', 'payment:mastercard', 'payment:visa', 'bench', 'information', 'bridge', 'attraction', 'lgbtq', 'ways', 'type', 'payment:coins', 'payment:cryptocurrencies', 'payment:electronic_purses', 'payment:notes', 'payment:visa_debit', 'former_name', 'architect:wikidata', 'architect:wikipedia', 'name:et', 'name:lt', 'name:ru', 'name:uk', 'wikimedia_commons']

# %%
# Count number of non-NaNs in each column
gdf.count()
# Out:
# source                 784
# geometry             38392
# amenity                809
# access                  19
# parking                 86
#                      ...
# name:et                  1
# name:lt                  1
# name:ru                  1
# name:uk                  1
# wikimedia_commons        1
# Length: 208, dtype: int64

# %%
# Filter cafes
cafes = gdf[gdf['amenity'] == 'cafe'].reset_index()
cafes
# Out:
#    element_type       osmid addr:state    building  ele gnis:county_id  \
# 0           way   123376983        NaN         yes  NaN            NaN
# 1           way   123493968        NaN         yes  NaN            NaN
# 2           way   221500325        NaN      retail  NaN            NaN
# 3           way   244977193        NaN         yes  NaN            NaN
# 4           way   244983219        NaN         yes  NaN            NaN
# 5           way   277456563        NaN         yes  NaN            NaN
# 6           way   283863396        NaN         yes  NaN            NaN
# 7           way   385083705        NaN  commercial  NaN            NaN
# 8           way   414520035        NaN         yes  NaN            NaN
# 9           way   420982688        NaN         yes  NaN            NaN
# 10          way   421453808        NaN         yes  NaN            NaN
# 11          way   424883136        NaN         yes  NaN            NaN
# 12          way   538960107        NaN         yes  NaN            NaN
# 13          way   719543503        NaN         yes  NaN            NaN
# 14          way   719543504        NaN         yes  NaN            NaN
# 15          way   763225361         OR         yes  NaN            NaN
# 16          way   763227943        NaN         yes  NaN            NaN
# 17          way   767743948        NaN         yes  NaN            NaN
# 18          way   771110244        NaN         yes  NaN            NaN
# 19          way   779175616        NaN      retail  NaN            NaN
# 20          way   793336374        NaN         yes  NaN            NaN
# 21          way   794483762        NaN         yes  NaN            NaN
# 22          way   829450689        NaN         yes  NaN            NaN
# 23          way   839134731        NaN         yes  NaN            NaN
# 24          way   842541371        NaN         yes  NaN            NaN
# 25          way   846616155        NaN         yes  NaN            NaN
# 26          way   860270565         OR         yes  NaN            NaN
# 27          way   871796702        NaN         yes  NaN            NaN
# 28          way   875651992        NaN         yes  NaN            NaN
# 29          way   881513127        NaN         yes  NaN            NaN
# 30          way   908567290        NaN         yes  NaN            NaN
# 31          way   910330366        NaN         yes  NaN            NaN
# 32          way   987240237        NaN         yes  NaN            NaN
# 33          way  1012479091        NaN         yes  NaN            NaN
# 34          way  1012479109        NaN         yes  NaN            NaN
#
#    gnis:created gnis:feature_id                          name operator  ...  \
# 0           NaN             NaN                   Latitude 10      NaN  ...
# 1           NaN             NaN                The Human Bean      NaN  ...
# 2           NaN             NaN              Brail's Expresso      NaN  ...
# 3           NaN             NaN    TopCity Frozen Yogurt Cafe      NaN  ...
# 4           NaN             NaN                     Starbucks      NaN  ...
# 5           NaN             NaN                 Espresso Roma      NaN  ...
# 6           NaN             NaN            Dutch Bros. Coffee      NaN  ...
# 7           NaN             NaN     Greenleaf Juicing Company      NaN  ...
# 8           NaN             NaN                      Romano's      NaN  ...
# 9           NaN             NaN               Voodoo Doughnut      NaN  ...
# 10          NaN             NaN            Dutch Bros. Coffee      NaN  ...
# 11          NaN             NaN            Dutch Bros. Coffee      NaN  ...
# 12          NaN             NaN                           NaN      NaN  ...
# 13          NaN             NaN          Coffee Plant Roaster      NaN  ...
# 14          NaN             NaN                     Starbucks      NaN  ...
# 15          NaN             NaN                 Amazon Coffee      NaN  ...
# 16          NaN             NaN               The Rabbit Hole      NaN  ...
# 17          NaN             NaN            Dutch Bros. Coffee      NaN  ...
# 18          NaN             NaN            Dutch Bros. Coffee      NaN  ...
# 19          NaN             NaN    Euphoria Chocolate Company      NaN  ...
# 20          NaN             NaN            Dutch Bros. Coffee      NaN  ...
# 21          NaN             NaN              Firehouse Coffee      NaN  ...
# 22          NaN             NaN              Java Generations      NaN  ...
# 23          NaN             NaN              Express Expresso      NaN  ...
# 24          NaN             NaN             Prime Time Coffee      NaN  ...
# 25          NaN             NaN                     Starbucks      NaN  ...
# 26          NaN             NaN  The Quick Fix Coffee Company      NaN  ...
# 27          NaN             NaN                The Human Bean      NaN  ...
# 28          NaN             NaN            Dutch Bros. Coffee      NaN  ...
# 29          NaN             NaN                     Starbucks      NaN  ...
# 30          NaN             NaN                     Metro Bru      NaN  ...
# 31          NaN             NaN                         J-TEA      NaN  ...
# 32          NaN             NaN            Dutch Bros. Coffee      NaN  ...
# 33          NaN             NaN                     Cafe Yumm      NaN  ...
# 34          NaN             NaN             Magpie Coffeeshop      NaN  ...
#
#    house:soliciting soliciting covered facebook opening_hours:url yelp  \
# 0               NaN        NaN     NaN      NaN               NaN  NaN
# 1               NaN        NaN     NaN      NaN               NaN  NaN
# 2               NaN        NaN     NaN      NaN               NaN  NaN
# 3               NaN        NaN     NaN      NaN               NaN  NaN
# 4               NaN        NaN     NaN      NaN               NaN  NaN
# 5               NaN        NaN     NaN      NaN               NaN  NaN
# 6               NaN        NaN     NaN      NaN               NaN  NaN
# 7               NaN        NaN     NaN      NaN               NaN  NaN
# 8               NaN        NaN     NaN      NaN               NaN  NaN
# 9               NaN        NaN     NaN      NaN               NaN  NaN
# 10              NaN        NaN     NaN      NaN               NaN  NaN
# 11              NaN        NaN     NaN      NaN               NaN  NaN
# 12              NaN        NaN     NaN      NaN               NaN  NaN
# 13              NaN        NaN     NaN      NaN               NaN  NaN
# 14              NaN        NaN     NaN      NaN               NaN  NaN
# 15              NaN        NaN     NaN      NaN               NaN  NaN
# 16              NaN        NaN     NaN      NaN               NaN  NaN
# 17              NaN        NaN     NaN      NaN               NaN  NaN
# 18              NaN        NaN     NaN      NaN               NaN  NaN
# 19              NaN        NaN     NaN      NaN               NaN  NaN
# 20              NaN        NaN     NaN      NaN               NaN  NaN
# 21              NaN        NaN     NaN      NaN               NaN  NaN
# 22              NaN        NaN     NaN      NaN               NaN  NaN
# 23              NaN        NaN     NaN      NaN               NaN  NaN
# 24              NaN        NaN     NaN      NaN               NaN  NaN
# 25              NaN        NaN     NaN      NaN               NaN  NaN
# 26              NaN        NaN     NaN      NaN               NaN  NaN
# 27              NaN        NaN     NaN      NaN               NaN  NaN
# 28              NaN        NaN     NaN      NaN               NaN  NaN
# 29              NaN        NaN     NaN      NaN               NaN  NaN
# 30              NaN        NaN     NaN      NaN               NaN  NaN
# 31              NaN        NaN     NaN      NaN               NaN  NaN
# 32              NaN        NaN     NaN      NaN               NaN  NaN
# 33              NaN        NaN     NaN      NaN               NaN  NaN
# 34              NaN        NaN     NaN      NaN               NaN  NaN
#
#    surface ways type contact:website
# 0      NaN  NaN  NaN             NaN
# 1      NaN  NaN  NaN             NaN
# 2      NaN  NaN  NaN             NaN
# 3      NaN  NaN  NaN             NaN
# 4      NaN  NaN  NaN             NaN
# 5      NaN  NaN  NaN             NaN
# 6      NaN  NaN  NaN             NaN
# 7      NaN  NaN  NaN             NaN
# 8      NaN  NaN  NaN             NaN
# 9      NaN  NaN  NaN             NaN
# 10     NaN  NaN  NaN             NaN
# 11     NaN  NaN  NaN             NaN
# 12     NaN  NaN  NaN             NaN
# 13     NaN  NaN  NaN             NaN
# 14     NaN  NaN  NaN             NaN
# 15     NaN  NaN  NaN             NaN
# 16     NaN  NaN  NaN             NaN
# 17     NaN  NaN  NaN             NaN
# 18     NaN  NaN  NaN             NaN
# 19     NaN  NaN  NaN             NaN
# 20     NaN  NaN  NaN             NaN
# 21     NaN  NaN  NaN             NaN
# 22     NaN  NaN  NaN             NaN
# 23     NaN  NaN  NaN             NaN
# 24     NaN  NaN  NaN             NaN
# 25     NaN  NaN  NaN             NaN
# 26     NaN  NaN  NaN             NaN
# 27     NaN  NaN  NaN             NaN
# 28     NaN  NaN  NaN             NaN
# 29     NaN  NaN  NaN             NaN
# 30     NaN  NaN  NaN             NaN
# 31     NaN  NaN  NaN             NaN
# 32     NaN  NaN  NaN             NaN
# 33     NaN  NaN  NaN             NaN
# 34     NaN  NaN  NaN             NaN
#
# [35 rows x 230 columns]

# %%
# Reproject to UTM Zone 10N
gdf = gdf.to_crs('EPSG:32610')
cafes = cafes.to_crs('EPSG:32610')

# %%
# Get coordinates of Condon Hall
condon_hall = gdf[gdf['name'] == 'Condon Hall'].reset_index()

# %%
# Get cafe and Condon Hall centroids
cafes['centroid'] = cafes['geometry'].apply(
  lambda x: x.centroid if type(x) == Polygon else (
  x.centroid if type(x) == MultiPolygon else x))

condon_hall['centroid'] = condon_hall['geometry'].apply(
  lambda x: x.centroid if type(x) == Polygon else (
  x.centroid if type(x) == MultiPolygon else x))

# %%
# Compute distances
condon_hall_x = condon_hall['centroid'].x.values[0]
condon_hall_y = condon_hall['centroid'].y.values[0]
distances = np.sqrt(((condon_hall_x - cafes['centroid'].x.values)**2)
                     + ((condon_hall_y - cafes['centroid'].y.values)**2))

# Add to GeoDataFrame
cafes['euclidean_distance'] = distances

# %%
print(cafes.nsmallest(10, ['euclidean_distance'])[['name', 'euclidean_distance']])
# Out:
#                          name  euclidean_distance
# 7   Greenleaf Juicing Company           53.254590
# 5               Espresso Roma          135.286656
# 10         Dutch Bros. Coffee          830.863412
# 16            The Rabbit Hole          994.588162
# 4                   Starbucks         1094.039455
# 2            Brail's Expresso         1225.004530
# 9             Voodoo Doughnut         1240.194485
# 15              Amazon Coffee         1296.503685
# 33                  Cafe Yumm         1335.694760
# 34          Magpie Coffeeshop         1349.524658

# %%
# Make a new DataFrame containing only the three most relevant columns
nearest_cafes = cafes.nsmallest(10, ['euclidean_distance'])[['name', 'euclidean_distance', 'centroid']]

# Set column geometry
nearest_cafes = nearest_cafes.set_geometry('centroid')

# Convert back to WGS84
nearest_cafes = nearest_cafes.to_crs('EPSG:4326')

# Import package
import folium

# Define center of map (i.e. Condon Hall) and initial zoom level
lat_lon = [44.0451, -123.0781]
m = folium.Map(location=lat_lon, zoom_start=15)

for i in range(0, nearest_cafes.shape[0]):
    my_string = 'name: {}, distance: {}'.format(nearest_cafes.iloc[i]['name'], nearest_cafes.iloc[i]['euclidean_distance'])
    folium.Marker([nearest_cafes.iloc[i]['centroid'].y, nearest_cafes.iloc[i]['centroid'].x],
                 popup=my_string).add_to(m)

# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_06346dfc5c8b44d38501846155f8f74d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_06346dfc5c8b44d38501846155f8f74d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_06346dfc5c8b44d38501846155f8f74d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_06346dfc5c8b44d38501846155f8f74d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B44.0451%2C%20-123.0781%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
gdf['religion'].unique()
# Out:
# array([nan, 'christian'], dtype=object)
